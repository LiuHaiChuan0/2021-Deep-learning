# %% [markdown]
# # 循环遍历cat文件夹下的猫咪种类，不能打开的就删除掉

# %%
from PIL import Image
path=r'.\data\1.jpg'
# image = Image.open(r'.\data\n02085620_473.jpg')

# %%
try:
    img = Image.open(path)
    
except Exception as e:
        print(e)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x582 at 0x18E89E73E50>
